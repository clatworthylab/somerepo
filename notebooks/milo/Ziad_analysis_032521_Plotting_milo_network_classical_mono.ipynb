# %%
import numpy as np
import pandas as pd
import scanpy as sc
import scrublet as scr
import os
import warnings
import functools
import seaborn as sns
import scipy.stats
import anndata
import dandelion as ddl
sc.logging.print_header()

warnings.filterwarnings('ignore')
os.chdir('/lustre/scratch117/cellgen/team297/kt16/Ziad/scanpy')
# Out:
# scanpy==1.7.1 anndata==0.7.5 umap==0.5.1 numpy==1.19.4 scipy==1.6.0 pandas==1.2.3 scikit-learn==0.23.2 statsmodels==0.12.1 python-igraph==0.8.3 leidenalg==0.8.3

# %%
rnax1 = sc.read_h5ad('h5ad/R/classical_mono_1.5_prep_milo.h5ad')
rnax2 = sc.read_h5ad('h5ad/R/classical_mono_2.5_prep_milo.h5ad')

# %%
import anndata2ri
import rpy2.rinterface_lib.callbacks
import logging

# %%
rpy2.rinterface_lib.callbacks.logger.setLevel(logging.ERROR)

# %%
anndata2ri.activate()

# %%
# %load_ext rpy2.ipython

# %%
# %%R -o dares1 -o dares2
# mylox1 <- readRDS('h5ad/R/milo_classical_mono_1.5.RDS')
# mylox2 <- readRDS('h5ad/R/milo_classical_mono_2.5.RDS')
# dares1 <- readRDS('h5ad/R/model_1/milo_results_1.5vsuntreated_classical_mono.RDS')
# dares2 <- readRDS('h5ad/R/model_1/milo_results_2.5vsuntreated_classical_mono.RDS')

# %%
# %%R -o nhood_graph1 -o nhood_graph2
# library(miloR)
# library(igraph)
# library(SingleCellExperiment)
# ## Save the adjacency matrix of the nhood graph
# nhood_graph1 = as_adjacency_matrix(nhoodGraph(mylox1), attr="weight")
# nhood_graph2 = as_adjacency_matrix(nhoodGraph(mylox2), attr="weight")

# %%
# %%R -o nh_umap_df1 -o nh_umap_df2
# ## Save the positions in UMAP of nhood indices
# nh_umap_df1 = reducedDim(mylox1, "UMAP")[unlist(nhoodIndex(mylox1)),]
# nh_umap_df2 = reducedDim(mylox2, "UMAP")[unlist(nhoodIndex(mylox2)),]

# %%
nhood_adata1 = sc.AnnData(obs = dares1)
nhood_adata2 = sc.AnnData(obs = dares2)

# %%
## Add graph
nhood_graph_conn1 = nhood_graph1.copy()
nhood_graph_conn1[nhood_graph_conn1 > 1] = 1 

nhood_adata1.uns["neighbors"] = {}
nhood_adata1.obsp['distances'] = nhood_graph1
nhood_adata1.uns['neighbors']["distances"] = nhood_graph1
nhood_adata1.obsp['connectivities'] = nhood_graph_conn1
nhood_adata1.uns['neighbors']["connectivities"] = nhood_graph_conn1

nhood_graph_conn2 = nhood_graph2.copy()
nhood_graph_conn2[nhood_graph_conn2 > 1] = 1 

nhood_adata2.uns["neighbors"] = {}
nhood_adata2.obsp['distances'] = nhood_graph2
nhood_adata2.uns['neighbors']["distances"] = nhood_graph2
nhood_adata2.obsp['connectivities'] = nhood_graph_conn2
nhood_adata2.uns['neighbors']["connectivities"] = nhood_graph_conn2

# %%
## Add umap positions
nhood_adata1.obsm["X_umap"] = nh_umap_df1
nhood_adata2.obsm["X_umap"] = nh_umap_df2

# %%
rnax1
# Out:
# AnnData object with n_obs × n_vars = 35429 × 3494
#     obs: 'sampleid', 'sampleid_study', 'timepoint', 'treatment', 'study_id', 'scrublet_score', 'n_genes', 'percent_mito', 'n_counts', 'is_doublet', 'filter_rna', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'leiden', 'initial_clustering', 'fine_clustering', 'treatment_timepoint', 'sex', 'age', 'peak_trop', 'BNP', 'on_treatment_CRP', 'AEs', 'treatment_group_1', 'treatment_group_2', 'Lymph', 'CD4', 'CD8', 'Treg', 'sample_id', 'leiden_mono'
#     var: 'gene_ids', 'feature_types', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'dendrogram_leiden_mono', 'fine_clustering_colors', 'hvg', 'leiden', 'leiden_colors', 'leiden_mono_colors', 'neighbors', 'pca', 'rank_genes_groups', 'study_id_colors', 'timepoint_colors', 'treatment_colors', 'treatment_timepoint_colors', 'umap'
#     obsm: 'X_pca', 'X_pca_harmony', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
sc.pl.umap(rnax1, color = ['fine_clustering', 'leiden_mono'])

# %%
sc.pl.umap(rnax2, color = 'leiden_mono')

# %%
nhood_adata1.obs["beta_signif"] = nhood_adata1.obs["beta"]
nhood_adata1.obs["beta_signif"][nhood_adata1.obs["SpatialFDR"] > 0.1] = np.nan
nhood_adata2.obs["beta_signif"] = nhood_adata2.obs["beta"]
nhood_adata2.obs["beta_signif"][nhood_adata2.obs["SpatialFDR"] > 0.1] = np.nan

# %%
from tools import diverging_cmp, get_hex

# %%
# newcmp = diverging_cmp(get_hex('cool', 5)[0], get_hex('cool', 5)[4])

# %%
ax = sc.pl.umap(nhood_adata1, show = False, size = 1)
sc.pl.umap(nhood_adata1, color="beta_signif", cmap='RdBu_r', size = [x*.1 for x in nhood_adata1.obs['Nhood']], ax = ax, vmax = np.nanmax(nhood_adata1.obs['beta_signif']), vmin = -np.nanmax(nhood_adata1.obs['beta_signif']))

# %%
ax = sc.pl.umap(nhood_adata2, show = False, size = 1)
sc.pl.umap(nhood_adata2, color="beta_signif", cmap='RdBu_r', size = [x*.1 for x in nhood_adata2.obs['Nhood']], ax = ax, vmax = np.nanmax(nhood_adata2.obs['beta_signif']), vmin = -np.nanmax(nhood_adata2.obs['beta_signif']))

# %%
rnax = sc.read_h5ad('h5ad/classical_mono_rna.h5ad')

# %%
rnax.obs['treatment_leiden_mono'] = [a +'_' +b for a,b in zip(rnax.obs['treatment_group_1'], rnax.obs['leiden_mono'])]

# %%
sc.tl.rank_genes_groups(rnax, groupby = 'treatment_leiden_mono', method = 'wilcoxon')
# Out:
# ... storing 'treatment_leiden_mono' as categorical

# %%
sc.pl.rank_genes_groups_dotplot(rnax, n_genes = 20, standard_scale = 'var', color_map = 'viridis', min_logfoldchange = 1)
# Out:
# WARNING: dendrogram data not found (using key=dendrogram_treatment_leiden_mono). Running `sc.tl.dendrogram` with default parameters. For fine tuning it is recommended to run `sc.tl.dendrogram` independently.
