# %%
import numpy as np
import pandas as pd
import scanpy as sc
import scrublet as scr
import os
import warnings
import functools
import seaborn as sns
import scipy.stats
import anndata
import dandelion as ddl
sc.logging.print_header()

warnings.filterwarnings('ignore')
os.chdir('/lustre/scratch117/cellgen/team297/kt16/Ziad/scanpy')
# Out:
# scanpy==1.7.1 anndata==0.7.5 umap==0.5.1 numpy==1.19.4 scipy==1.6.0 pandas==1.2.3 scikit-learn==0.23.2 statsmodels==0.12.1 python-igraph==0.8.3 leidenalg==0.8.3

# %%
rnax1 = sc.read_h5ad('h5ad/R/TNK_1.5_prep_milo.h5ad')
rnax2 = sc.read_h5ad('h5ad/R/TNK_2.5_prep_milo.h5ad')

# %%
import anndata2ri
import rpy2.rinterface_lib.callbacks
import logging

# %%
rpy2.rinterface_lib.callbacks.logger.setLevel(logging.ERROR)

# %%
anndata2ri.activate()

# %%
# %load_ext rpy2.ipython

# %%
# %%R -o dares1 -o dares2
# mylox1 <- readRDS('h5ad/R/milo_TNK_1.5.RDS')
# mylox2 <- readRDS('h5ad/R/milo_TNK_2.5.RDS')
# dares1 <- readRDS('h5ad/R/model_1/milo_results_1.5vsuntreated_TNK.RDS')
# dares2 <- readRDS('h5ad/R/model_1/milo_results_2.5vsuntreated_TNK.RDS')

# %%
# %%R -o nhood_graph1 -o nhood_graph2
# library(miloR)
# library(igraph)
# library(SingleCellExperiment)
# ## Save the adjacency matrix of the nhood graph
# nhood_graph1 = as_adjacency_matrix(nhoodGraph(mylox1), attr="weight")
# nhood_graph2 = as_adjacency_matrix(nhoodGraph(mylox2), attr="weight")

# %%
# %%R -o nh_umap_df1 -o nh_umap_df2
# ## Save the positions in UMAP of nhood indices
# nh_umap_df1 = reducedDim(mylox1, "UMAP")[unlist(nhoodIndex(mylox1)),]
# nh_umap_df2 = reducedDim(mylox2, "UMAP")[unlist(nhoodIndex(mylox2)),]

# %%
nhood_adata1 = sc.AnnData(obs = dares1)
nhood_adata2 = sc.AnnData(obs = dares2)

# %%
## Add graph
nhood_graph_conn1 = nhood_graph1.copy()
nhood_graph_conn1[nhood_graph_conn1 > 1] = 1 

nhood_adata1.uns["neighbors"] = {}
nhood_adata1.obsp['distances'] = nhood_graph1
nhood_adata1.uns['neighbors']["distances"] = nhood_graph1
nhood_adata1.obsp['connectivities'] = nhood_graph_conn1
nhood_adata1.uns['neighbors']["connectivities"] = nhood_graph_conn1

nhood_graph_conn2 = nhood_graph2.copy()
nhood_graph_conn2[nhood_graph_conn2 > 1] = 1 

nhood_adata2.uns["neighbors"] = {}
nhood_adata2.obsp['distances'] = nhood_graph2
nhood_adata2.uns['neighbors']["distances"] = nhood_graph2
nhood_adata2.obsp['connectivities'] = nhood_graph_conn2
nhood_adata2.uns['neighbors']["connectivities"] = nhood_graph_conn2

# %%
## Add umap positions
nhood_adata1.obsm["X_umap"] = nh_umap_df1
nhood_adata2.obsm["X_umap"] = nh_umap_df2

# %%
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

sc.set_figure_params(figsize = (6,4), dpi_save = 900, vector_friendly=True)
sc.pl.umap(rnax1, color = 'fine_clustering', palette = {
    'CD16neg_NK':'#e7d4e8',
    'CD16pos_NK':'#c2a5cf',
    'CD16pos_SIGLEC7_NK':'#9970ab',
    'NKT':'#762a83',
    'CD4_Tnaive':'#d9f0d3',
    'CD4_Tcm':'#a6dba0',
    'CD4_Tem':'#5aae61',
    'CD4_Th2':'#1b7837',
    'CD4_Treg':'#00441b',
    'CD8_Tnaive':'#ff9d9a',
    'CD8_Tem':'#df65b0',
    'CD8_Temra':'#ce1256',
    'Vd1_gdT':'#f1ce63',
    'Vd2_gdT':'#b6992d',
    'MAIT':'#9d7763'}, legend_loc = 'on data', save = '_TNK_fine_clustering_2.pdf', legend_fontsize = 5)
# Out:
# WARNING: saving figure to file figures/umap_TNK_fine_clustering_2.pdf

# %%
nhood_adata1.obs["beta_signif"] = nhood_adata1.obs["beta"]
nhood_adata1.obs["beta_signif"][nhood_adata1.obs["SpatialFDR"] > 0.1] = np.nan
nhood_adata2.obs["beta_signif"] = nhood_adata2.obs["beta"]
nhood_adata2.obs["beta_signif"][nhood_adata2.obs["SpatialFDR"] > 0.1] = np.nan

# %%
sc.set_figure_params(figsize = (5.5,4), dpi_save = 900, vector_friendly=True)
ax = sc.pl.umap(nhood_adata1, show = False, size = 1)
sc.pl.umap(nhood_adata1, color="beta_signif", cmap='RdBu_r', size = [x*.1 for x in nhood_adata1.obs['Nhood']], ax = ax, vmax = np.nanmax(nhood_adata2.obs['beta_signif']), vmin = -np.nanmax(nhood_adata2.obs['beta_signif']), save= '_1.5MIU_milo_network')
# Out:
# WARNING: saving figure to file figures/umap_1.5MIU_milo_network.pdf

# %%
ax = sc.pl.umap(nhood_adata2, show = False, size = 1)
sc.pl.umap(nhood_adata2, color="beta_signif", cmap='RdBu_r', size = [x*.1 for x in nhood_adata2.obs['Nhood']], ax = ax, vmax = np.nanmax(nhood_adata2.obs['beta_signif']), vmin = -np.nanmax(nhood_adata2.obs['beta_signif']), save= '_2.5MIU_milo_network')
# Out:
# WARNING: saving figure to file figures/umap_2.5MIU_milo_network.pdf
