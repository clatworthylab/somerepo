# %%
import numpy as np
import pandas as pd
import scanpy as sc
import scrublet as scr
import os
import warnings
import functools
import seaborn as sns
import scipy.stats
import anndata
import dandelion as ddl
sc.logging.print_header()

warnings.filterwarnings('ignore')
os.chdir('/lustre/scratch117/cellgen/team297/kt16/Ziad/scanpy')
# Out:
# scanpy==1.6.0 anndata==0.7.4 umap==0.4.6 numpy==1.18.5 scipy==1.4.1 pandas==1.1.3 scikit-learn==0.23.2 statsmodels==0.12.0 python-igraph==0.7.1 leidenalg==0.8.2

# %%
rna = sc.read_h5ad('h5ad/TNK_rna.h5ad')

# %%
sc.pl.umap(rna, color=['fine_clustering'], legend_loc ='on data', legend_fontoutline=2)

# %%
sc.pl.dotplot(rna, ['CD3G', 'CD3E', 'CD3D', 'CD4', 'CD40LG', 'CD8A', 'CD8B', 'NCAM1', 'NKG7', 'TRAC', 'TRDC', 'IL7R', 'IL12RB1', 'ZBTB16', 'CXCR3', 'IKZF3', 'EOMES', 'IFNG', 'KIT', 'PCDH9', 'ZBTB16'], groupby = 'fine_clustering', color_map = 'PuRd', standard_scale = 'var')
